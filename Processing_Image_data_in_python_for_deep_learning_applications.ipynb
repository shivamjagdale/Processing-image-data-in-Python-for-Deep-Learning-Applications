# %%
# Below program shows how we can process image so that we can feed it to the Deep Learning Algorithm.
# The steps we will carry out are :-

# Loading image using Matplotlib
# Numpy array to image
# Resizing the image with Pillow
# RGB to greyscale

# %%
# !wget "https://i.pinimg.com/736x/26/a5/f3/26a5f3b1386ca44a80e46e9817c76aa9.jpg"
# Out:
# --2024-07-15 03:51:06--  https://i.pinimg.com/736x/26/a5/f3/26a5f3b1386ca44a80e46e9817c76aa9.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 23.199.34.114, 23.199.34.112, 2600:1417:76::17d2:d720, ...
# Connecting to i.pinimg.com (i.pinimg.com)|23.199.34.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85742 (84K) [image/jpeg]
# Saving to: ‘26a5f3b1386ca44a80e46e9817c76aa9.jpg’
#
# 26a5f3b1386ca44a80e 100%[===================>]  83.73K  --.-KB/s    in 0.02s
#
# 2024-07-15 03:51:07 (5.35 MB/s) - ‘26a5f3b1386ca44a80e46e9817c76aa9.jpg’ saved [85742/85742]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/content/Dog.jpg')

# %%
img
# Out:
# array([[[128,  41,  86],
#         [128,  41,  86],
#         [129,  42,  85],
#         ...,
#         [175,  67,  18],
#         [166,  61,  13],
#         [160,  55,   7]],
#
#        [[127,  41,  86],
#         [127,  41,  86],
#         [128,  42,  87],
#         ...,
#         [175,  68,  16],
#         [166,  62,  11],
#         [160,  55,   7]],
#
#        [[124,  41,  87],
#         [125,  42,  86],
#         [125,  42,  86],
#         ...,
#         [176,  69,  15],
#         [166,  62,   9],
#         [161,  57,   6]],
#
#        ...,
#
#        [[ 70,  98, 112],
#         [ 69,  98, 112],
#         [ 70,  97, 114],
#         ...,
#         [ 83,  51,  26],
#         [ 82,  50,  25],
#         [ 81,  49,  24]],
#
#        [[ 69,  98, 114],
#         [ 67,  98, 116],
#         [ 69,  97, 118],
#         ...,
#         [ 81,  49,  24],
#         [ 80,  48,  23],
#         [ 79,  47,  22]],
#
#        [[ 66,  97, 115],
#         [ 66,  97, 115],
#         [ 66,  97, 118],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1200, 675, 3)

# %% [markdown]
# #**Numpy array to image**

# %%
image = plt.imshow(img)

# %% [markdown]
# #**Resizing the image**

# %%
from PIL import Image

img = Image.open('/content/Dog.jpg')
img_resized = img.resize((200,200))

img_resized.save('resized_image.jpg')

# %%
# Loading the resized image in matplot

img22 = mpimg.imread('/content/resized_image.jpg')

# %%
img11 = plt.imshow(img22)

# %%
img22.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# #**RGB to Greyscale image**

# %%
import cv2

# %%
img = cv2.imread('/content/Dog.jpg')

# %%
img.shape
# Out:
# (1200, 675, 3)

# %%
greyscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(greyscale_image)
# Out:
# numpy.ndarray

# %%
greyscale_image.shape
# Out:
# (1200, 675)

# %%
black_white = plt.imshow(greyscale_image)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(greyscale_image)
# Out:
# <PIL.Image.Image image mode=L size=675x1200>

# %%
cv2.imwrite('dog_greyscale.jpg', greyscale_image)
#saves the image
# Out:
# True
